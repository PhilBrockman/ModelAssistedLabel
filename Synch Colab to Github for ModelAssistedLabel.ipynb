# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
token_dir = "/content/drive/MyDrive/API Tokens"
f = open(f"{token_dir}/ModelAssistedLabel repo.txt")
api_token = f.read()
f.close()
# Out:
# Cloning into 'ModelAssistedLabel'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 95 (delta 38), reused 51 (delta 15), pack-reused 0
# Unpacking objects: 100% (95/95), done.

# %%
pip install nbdev

# %%
# !nbdev_build_lib
# !nbdev_build_docs
# Out:
# Converted 00_core.ipynb.
# Converted 01_train.ipynb.
# Converted index.ipynb.
# converting: /content/drive/My Drive/Coding/ModelAssistedLabel/00_core.ipynb
# converting: /content/drive/My Drive/Coding/ModelAssistedLabel/01_train.ipynb
# converting /content/drive/My Drive/Coding/ModelAssistedLabel/index.ipynb to README.md

# %%
# !git config --global user.email "phil.brockman@gmail.com"
# !git config --global user.name "Phil Brockman"
# !git add *
# !git commit -m "updating docs"
# Out:
# [master b891826] updating docs
#  8 files changed, 490 insertions(+), 2525 deletions(-)
#  rewrite 00_core.ipynb (99%)
#  rewrite 01_train.ipynb (99%)
#  rewrite docs/core.html (96%)

# %%
# !git remote set-url origin https://PhilBrockman:{api_token}@github.com/PhilBrockman/ModelAssistedLabel.git
# !git push
# Out:
# Counting objects: 14, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (14/14), 12.99 KiB | 738.00 KiB/s, done.
# Total 14 (delta 8), reused 0 (delta 0)
# remote: Resolving deltas: 100% (8/8), completed with 7 local objects.
# To https://github.com/PhilBrockman/ModelAssistedLabel.git
#    c9534a4..b891826  master -> master
